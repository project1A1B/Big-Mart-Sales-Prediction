# %%
# 1. Problem Statement
  The data scientists at BigMart have collected sales data for 1559 products across 10 stores in different cities for the year 2013.
    Now each product has certain attributes that sets it apart from other products.

# 2. Hypothesis Generation
"""
1. Item Type Impact: We hypothesize that different product categories influence sales differently, with specific items potentially driving higher sales.

2. Location and Size Factors: Our hypothesis suggests that the location and size of outlets play key roles in sales variation, impacting revenue generation.

3. Price Sensitivity and Outlet Type: We expect that consumer price sensitivity, influenced by maximum retail price and store type, contributes to differences in sales outcomes.
"""

# 3. Loading Packages and Data
# Import necessary Python libraries/packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset (replace 'your_dataset.csv' with the actual file path)
data = pd.read_csv("C:\\Users\\HP\\Desktop\\Test.csv")

# 4. Data Structure and Content
# Display basic information about the dataset
print("Dataset Information:")
print(data.info())

# Display the first few rows of the dataset
print("\nFirst Few Rows of the Dataset:")
print(data.head())

# Summary statistics of the dataset
print("\nSummary Statistics:")
print(data.describe())

# Check for missing values
print("\nMissing Values:")
print(data.isnull().sum())

# Check unique values in categorical columns
print("\nUnique Values in Categorical Columns:")
categorical_columns = data.select_dtypes(include=['object']).columns
for column in categorical_columns:
    print(f"{column}: {data[column].unique()}")

# Visualize the data (e.g., histograms, box plots, etc.) to get an initial understanding
# Example: sns.histplot(data=data, x='Item_MRP', bins=20, kde=True)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB
# None
#
# First Few Rows of the Dataset:
# ...

# %%
 

# Load the dataset (replace 'your_dataset.csv' with the actual file path)
datatrain = pd.read_csv(r'C:\Users\HP\Desktop\Train.csv')

# 4. Data Structure and Content
# Display basic information about the dataset
print("Dataset Information:")
print(datatrain.info())

# Display the first few rows of the dataset
print("\nFirst Few Rows of the Dataset:")
print(datatrain.head())

# Summary statistics of the dataset
print("\nSummary Statistics:")
print(datatrain.describe())

# Check for missing values
print("\nMissing Values:")
print(datatrain.isnull().sum())

# Check unique values in categorical columns
print("\nUnique Values in Categorical Columns:")
categorical_columns = datatrain.select_dtypes(include=['object']).columns
for column in categorical_columns:
    print(f"{column}: {data[column].unique()}")

# Visualize the data (e.g., histograms, box plots, etc.) to get an initial understanding
# Example: sns.histplot(data=data, x='Item_MRP', bins=20, kde=True)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# ...

# %%
# Load the second dataset
testdataset = pd.read_csv(r"C:\Users\HP\Desktop\Test.csv")

print(testdataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB
# None

# %%
# Load the first dataset
traindataset = pd.read_csv(r'C:\Users\HP\Desktop\Train.csv')
testdataset = pd.read_csv(r'C:\Users\HP\Desktop\Test.csv')


# Display basic information about the datasets
print("traindataset Info:")
print(traindataset.info())

print("testdataset Info:")
print(testdataset.info())
# Out:
# traindataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# ...

# %%
# Summary statistics for dataset 1
summary_stats1 = traindataset.describe()

# Summary statistics for dataset 2
summary_stats2 = testdataset.describe()

print("Summary Statistics for test dataset :")
print(summary_stats1)

print("\nSummary Statistics for train dataset :")
print(summary_stats2)
# Out:
# Summary Statistics for test dataset :
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot a histogram of Item_Weight for dataset 1 (excluding missing values)
plt.figure(figsize=(8, 6))
sns.histplot(data=testdataset.dropna(), x='Item_Weight', bins=20, kde=True)
plt.title("Histogram of Item_Weight (test dataset )")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")
plt.show()

# Plot a boxplot of Item_Outlet_Sales for dataset 1
plt.figure(figsize=(8, 6))
sns.boxplot(data=traindataset, x='Item_Outlet_Sales')
plt.title("Boxplot of Item_Outlet_Sales (test dataset)")
plt.xlabel("Item_Outlet_Sales")
plt.show()

# Create a countplot of Item_Fat_Content for dataset 2
plt.figure(figsize=(8, 6))
sns.countplot(data=testdataset, x='Item_Fat_Content')
plt.title("Countplot of Item_Fat_Content (train dataset)")
plt.xlabel("Item_Fat_Content")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Univariante Analysis

# %%
# Select the variables for univariate analysis in both datasets (e.g., 'Item_Weight')
variable_of_interest1 = 'Item_Weight'
variable_of_interest2 = 'Item_Weight'

# Define a function for univariate analysis
def univariate_analysis(data, variable_of_interest, dataset_name):
    # 1. Basic Summary Statistics
    # Calculate and display basic statistics for the selected variable
    print(f"Basic Statistics for {variable_of_interest} in {dataset_name}")
    print("Mean:", data[variable_of_interest].mean())
    print("Median:", data[variable_of_interest].median())
    print("Standard Deviation:", data[variable_of_interest].std())
    print("Minimum:", data[variable_of_interest].min())
    print("Maximum:", data[variable_of_interest].max())

    # 2. Histogram
    # Create a histogram to visualize the distribution of the variable
    plt.figure(figsize=(8, 6))
    sns.histplot(data=data, x=variable_of_interest, bins=20, kde=True)
    plt.title(f"Histogram of {variable_of_interest} in {dataset_name}")
    plt.xlabel(variable_of_interest)
    plt.ylabel("Frequency")
    plt.show()

    # 3. Box Plot
    # Create a box plot to visualize the summary statistics and potential outliers
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=data, y=variable_of_interest)
    plt.title(f"Box Plot of {variable_of_interest} in {dataset_name}")
    plt.ylabel(variable_of_interest)
    plt.show()

    # 4. Value Counts for Categorical Variables
    # If the variable is categorical, you can count the occurrences of each category
    # Example: For a 'Category' column: data['Category'].value_counts()

    # 5. Check for Missing Values
    # Check if there are any missing values in the variable
    missing_values = data[variable_of_interest].isnull().sum()
    print(f"Missing Values in {variable_of_interest} in {dataset_name}: {missing_values}")

    # 6. Additional Visualizations or Analyses as needed

# Perform univariate analysis for the first dataset
univariate_analysis(testdataset, variable_of_interest1, 'Test Dataset')

# Perform univariate analysis for the second dataset
univariate_analysis(traindataset, variable_of_interest2, 'Train Dataset')
# Out:
# Basic Statistics for Item_Weight in Test Dataset
# Mean: 12.695633368756642
# Median: 12.5
# Standard Deviation: 4.664848587385391
# Minimum: 4.555
# Maximum: 21.35
# Missing Values in Item_Weight in Test Dataset: 976
# Basic Statistics for Item_Weight in Train Dataset
# Mean: 12.857645184135976
# Median: 12.6
# Standard Deviation: 4.643456499186395
# Minimum: 4.555
# Maximum: 21.35
# Missing Values in Item_Weight in Train Dataset: 1463

# %% [markdown]
# # Bivariate Analysis

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(traindataset['Item_Weight'], traindataset['Item_Outlet_Sales'], alpha=0.5)
plt.title('Scatterplot: Item_Weight vs Item_Outlet_Sales (test Dataset)')
plt.xlabel('Item_Weight')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %% [markdown]
# # Missing Value Treatment

# %%
# Function to handle missing values in a dataset
def handle_missing_values(data, dataset_name):
    # 1. Check for Missing Values
    missing_values = data.isnull().sum()

    # 2. Display Missing Values
    print(f"Missing Values in {dataset_name}:\n{missing_values}")

    # 3. Handle Missing Values
    # You can choose a suitable method for handling missing values, such as:
    # a. Removing rows with missing values
    #    data.dropna(inplace=True)

    # b. Filling missing values with a specific value (e.g., mean, median, mode)
    #    data['column_name'].fillna(data['column_name'].mean(), inplace=True)

    # c. Interpolating missing values
    #    data.interpolate(method='linear', inplace=True)

    # d. Using a placeholder value
    #    data['column_name'].fillna('Not Available', inplace=True)

# Handle missing values for the first dataset
handle_missing_values(testdataset, 'Test Dataset')

# Handle missing values for the second dataset
handle_missing_values(traindataset, 'Train Dataset')

# After handling missing values, you can save the cleaned datasets if needed
# dataset1.to_csv('cleaned_dataset1.csv', index=False)
# dataset2.to_csv('cleaned_dataset2.csv', index=False)
# Out:
# Missing Values in Test Dataset:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64
# Missing Values in Train Dataset:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
# Function for Feature Engineering
def feature_engineering(data, dataset_name):
    # Example feature engineering: Creating a new feature 'MRP_to_Weight_Ratio'
    data['MRP_to_Weight_Ratio'] = data['Item_MRP'] / data['Item_Weight']
    
    # You can add more feature engineering steps here based on your domain knowledge and dataset characteristics
    
    # Print a summary of the new features created
    print(f"Summary of Feature Engineering in {dataset_name}:\n{data[['Item_MRP', 'Item_Weight', 'MRP_to_Weight_Ratio']].head()}")

# Perform feature engineering for the first dataset
feature_engineering(testdataset, 'Test Dataset ')

# Perform feature engineering for the second dataset
feature_engineering(traindataset, 'Train Dataset ')

# After feature engineering, you can save the datasets with the new features if needed
# dataset1.to_csv('feature_engineered_dataset1.csv', index=False)
# dataset2.to_csv('feature_engineered_dataset2.csv', index=False)
# Out:
# Summary of Feature Engineering in Test Dataset :
#    Item_MRP  Item_Weight  MRP_to_Weight_Ratio
# 0  107.8622       20.750             5.198178
# 1   87.3198        8.300            10.520458
# 2  241.7538       14.600            16.558479
# 3  155.0340        7.315            21.193985
# 4  234.2300          NaN                  NaN
# Summary of Feature Engineering in Train Dataset :
#    Item_MRP  Item_Weight  MRP_to_Weight_Ratio
# 0  249.8092         9.30            26.861204
# 1   48.2692         5.92             8.153581
# 2  141.6180        17.50             8.092457
# 3  182.0950        19.20             9.484115
# 4   53.8614         8.93             6.031512

# %% [markdown]
# # Encoding Categorical Variables

# %%
# Identify the categorical columns in each dataset
categorical_cols1 = ["Item_Fat_Content", "Item_Type", "Outlet_Identifier", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"]
categorical_cols2 = ["Item_Fat_Content", "Item_Type", "Outlet_Identifier", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"]

# Perform one-hot encoding for the first dataset
testdataset_encoded = pd.get_dummies(testdataset, columns=categorical_cols1, drop_first=True)

# Perform one-hot encoding for the second dataset
traindataset_encoded = pd.get_dummies(traindataset, columns=categorical_cols2, drop_first=True)

# Display the first few rows of the encoded datasets
print("Encoded testdataset:")
print(testdataset_encoded.head())

print("\nEncoded traindataset:")
print(traindataset_encoded.head())
# Out:
# Encoded testdataset:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0           FDW58       20.750         0.007565  107.8622
# 1           FDW14        8.300         0.038428   87.3198
# 2           NCN55       14.600         0.099575  241.7538
# 3           FDQ58        7.315         0.015388  155.0340
# 4           FDY38          NaN         0.118599  234.2300
#
#    Outlet_Establishment_Year  MRP_to_Weight_Ratio  Item_Fat_Content_Low Fat  \
# 0                       1999             5.198178                         1
# 1                       2007            10.520458                         0
# 2                       1998            16.558479                         1
# 3                       2007            21.193985                         1
# 4                       1985                  NaN                         0
#
#    Item_Fat_Content_Regular  Item_Fat_Content_low fat  Item_Fat_Content_reg  \
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Identify the categorical columns in each dataset
categorical_cols1 = ["Item_Fat_Content", "Item_Type", "Outlet_Identifier", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"]
categorical_cols2 = ["Item_Fat_Content", "Item_Type", "Outlet_Identifier", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"]

# Perform label encoding for the first dataset
data1_encoded = testdataset.copy()
label_encoder1 = LabelEncoder()
for col in categorical_cols1:
    data1_encoded[col] = label_encoder1.fit_transform(testdataset[col])

# Perform label encoding for the second dataset
data2_encoded = traindataset.copy()
label_encoder2 = LabelEncoder()
for col in categorical_cols2:
    data2_encoded[col] = label_encoder2.fit_transform(traindataset[col])

# Display the first few rows of the encoded datasets
print("Encoded testdataset:")
print(data1_encoded.head())

print("\nEncoded traindataset:")
print(data2_encoded.head())
# Out:
# Encoded testdataset:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDW58       20.750                 1         0.007565         13
# 1           FDW14        8.300                 4         0.038428          4
# 2           NCN55       14.600                 1         0.099575         11
# 3           FDQ58        7.315                 1         0.015388         13
# 4           FDY38          NaN                 2         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999            1
# 1   87.3198                  2                       2007            3
# 2  241.7538                  0                       1998            3
# 3  155.0340                  2                       2007            3
# 4  234.2300                  5                       1985            1
#
# ...

# %% [markdown]
# # One Hot Encoding

# %%
# Identify the categorical columns in each dataset
categorical_cols1 = ["Item_Fat_Content", "Item_Type", "Outlet_Identifier", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"]
categorical_cols2 = ["Item_Fat_Content", "Item_Type", "Outlet_Identifier", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"]

# Perform one-hot encoding for the first dataset
testdataset_encoded = pd.get_dummies(testdataset, columns=categorical_cols1, prefix=categorical_cols1, drop_first=True)

# Perform one-hot encoding for the second dataset
traindataset_encoded = pd.get_dummies(traindataset, columns=categorical_cols2, prefix=categorical_cols2, drop_first=True)

# Display the first few rows of the encoded datasets
print("Encoded test dataset:")
print(testdataset_encoded.head())

print("\nEncoded train dataset :")
print(traindataset_encoded.head())
# Out:
# Encoded test dataset:
#    Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0            FDW58       20.750         0.007565  107.8622
# 5            FDH56        9.800         0.063817  117.1492
# 6            FDL48       19.350         0.082602   50.1034
# 13           FDU11        4.785         0.092738  122.3098
# 14           DRL59       16.750         0.021206   52.0298
#
#     Outlet_Establishment_Year  MRP_to_Weight_Ratio  Item_Fat_Content_Low Fat  \
# 0                        1999             5.198178                         1
# 5                        1997            11.954000                         0
# 6                        2009             2.589323                         0
# 13                       1999            25.561087                         1
# 14                       1987             3.106257                         0
#
#     Item_Fat_Content_Regular  Item_Fat_Content_low fat  Item_Fat_Content_reg  \
# ...

# %%
# Ensure that non-numeric columns are excluded from X_train and X_test
X_train = traindataset_encoded.drop(columns=['Item_Outlet_Sales', 'Item_Identifier'])  # Exclude 'Item_Identifier'
y_train = traindataset_encoded['Item_Outlet_Sales']

X_test = testdataset_encoded.drop(columns=['Item_Identifier'])  # Exclude 'Item_Identifier'

# Now, you can apply feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Split the dataset into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X_train_scaled, y_train, test_size=0.2, random_state=42)

# Linear Regression
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
linear_reg_pred = linear_reg.predict(X_valid)

# Ridge Regression
ridge_reg = Ridge(alpha=1.0)  # You can adjust the alpha parameter
ridge_reg.fit(X_train, y_train)
ridge_reg_pred = ridge_reg.predict(X_valid)

# Lasso Regression
lasso_reg = Lasso(alpha=1.0)  # You can adjust the alpha parameter
lasso_reg.fit(X_train, y_train)
lasso_reg_pred = lasso_reg.predict(X_valid)

# RandomForest
random_forest = RandomForestRegressor(n_estimators=100, random_state=42)  # You can adjust the number of estimators
random_forest.fit(X_train, y_train)
random_forest_pred = random_forest.predict(X_valid)

# XGBoost
xgboost = XGBRegressor(n_estimators=100, random_state=42)  # You can change the number of estimators as needed
xgboost.fit(X_train, y_train)
xgboost_pred = xgboost.predict(X_valid)

# Evaluate models
def evaluate_model(model_name, y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{model_name} MSE: {mse}")
    print(f"{model_name} R-squared: {r2}")

print("Linear Regression Evaluation:")
evaluate_model("Linear Regression", y_valid, linear_reg_pred)

print("\nRidge Regression Evaluation:")
evaluate_model("Ridge Regression", y_valid, ridge_reg_pred)

print("\nLasso Regression Evaluation:")
evaluate_model("Lasso Regression", y_valid, lasso_reg_pred)

print("\nRandomForest Evaluation:")
evaluate_model("RandomForest", y_valid, random_forest_pred)

print("\nXGBoost Evaluation:")
evaluate_model("XGBoost", y_valid, xgboost_pred)
# Out:
# Linear Regression Evaluation:
# Linear Regression MSE: 1090128.4454064432
# Linear Regression R-squared: 0.4955343266843262
#
# Ridge Regression Evaluation:
# Ridge Regression MSE: 1089809.3873590317
# Ridge Regression R-squared: 0.4956819733523793
#
# Lasso Regression Evaluation:
# Lasso Regression MSE: 1088775.7743142645
# Lasso Regression R-squared: 0.4961602860711911
#
# RandomForest Evaluation:
# RandomForest MSE: 1201621.6309576016
# RandomForest R-squared: 0.44393996167516037
#
# XGBoost Evaluation:
# XGBoost MSE: 1386848.0415394153
# XGBoost R-squared: 0.35822495595841497

# %% [markdown]
# # Summary
# In this analysis, various regression models were evaluated to predict sales. Linear Regression, Ridge Regression, and Lasso Regression exhibited similar performance, explaining approximately 49.6% of the variance in sales with an MSE of around 1,088,775.77. RandomForest and XGBoost, while capable, demonstrated slightly lower performance, suggesting that linear models are suitable for this sales prediction task.
